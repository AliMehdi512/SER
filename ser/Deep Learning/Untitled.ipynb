# %%
pip install streamlit keras librosa pydub --break-system-packages
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 936.7 kB/s eta 0:00:0031m1.1 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 1.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.2/731.2 kB 847.4 kB/s eta 0:00:00m eta 0:00:010:01:01
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.6/207.6 kB 859.4 kB/s eta 0:00:000:00:01m eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 MB 570.1 kB/s eta 0:00:00m eta 0:00:010:00:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 657.6 kB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 693.9 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# ...

# %%
import subprocess
import sys

# Replace 'app.py' with your Streamlit script filename
command = [sys.executable, "-m", "streamlit", "run", "app.py"]

# Launch Streamlit app
process = subprocess.Popen(command)
# Out:
#       👋 Welcome to Streamlit!
#
#       If you’d like to receive helpful onboarding emails, news, offers, promotions,
#       and the occasional swag, please enter your email address below. Otherwise,
#       leave this field blank.
#
#       Email:
# 2025-05-03 13:41:12.333
